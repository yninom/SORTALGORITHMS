# %% [markdown]
# # Homework 1
#
# 1. ¿Which algorithm is better? Plot them individually and all in one graph.
# - $TA(n)=1000n$
# - $TB(n)=200n\log{n}$
# - $TC(n)=10n^{2}$
# - $TD(n)=2^{n}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

n=np.arange(1e-7, 100, 0.1)
ta=1000*n
tb=200*n*np.log(n)
tc=10*np.power(n,2)
td=np.power(2,n)

figure, axis = plt.subplots(2, 2)
  
axis[0, 0].plot(n, ta)
axis[0, 0].set_title("TA")
axis[0, 1].plot(n, tb)
axis[0, 1].set_title("TB")
axis[1, 0].plot(n, tc)
axis[1, 0].set_title("TC")
axis[1, 1].plot(n, td)
axis[1, 1].set_title("TD")
  
plt.show()

# %%
n=np.arange(1e-7, 10, 0.1)
ta=1000*n
tb=200*n*np.log(n)
tc=10*np.power(n,2)
td=np.power(2,n)
plt.plot(n,ta,'r',label='TA')
plt.plot(n,tb,'b',label='TB')
plt.plot(n,tc,'g',label='TC')
plt.plot(n,td,'k',label='TD')
plt.ylabel('$O(n)$: operations')
plt.xlabel('$n$: data points')
plt.legend()
plt.show()

# %%
n=np.arange(10, 15, 0.1)
ta=1000*n
tb=200*n*np.log(n)
tc=10*np.power(n,2)
td=np.power(2,n)
plt.plot(n,ta,'r',label='TA')
plt.plot(n,tb,'b',label='TB')
plt.plot(n,tc,'g',label='TC')
plt.plot(n,td,'k',label='TD')
plt.ylabel('$O(n)$: operations')
plt.xlabel('$n$: data points')
plt.legend()
plt.show()

# %%
n=np.arange(10, 100, 0.1)
ta=1000*n
tb=200*n*np.log(n)
tc=10*np.power(n,2)
td=np.power(2,n)
plt.plot(n,ta,'r',label='TA')
plt.plot(n,tb,'b',label='TB')
plt.plot(n,tc,'g',label='TC')
#plt.plot(n,td,'k',label='TD')
plt.ylabel('$O(n)$: operations')
plt.xlabel('$n$: data points')
plt.legend()
plt.show()

# %%
n=np.arange(100, 1000, 0.1)
ta=1000*n
tb=200*n*np.log(n)
tc=10*np.power(n,2)
td=np.power(2,n)
plt.plot(n,ta,'r',label='TA')
plt.plot(n,tb,'b',label='TB')
plt.plot(n,tc,'g',label='TC')
#plt.plot(n,td,'k',label='TD')
plt.ylabel('$O(n)$: operations')
plt.xlabel('$n$: data points')
plt.legend()
plt.show()

# %% [markdown]
# In the previous graphs we can observe the complexity of the algorithms proposed as a function of the size of the input. TA represents a linear complexity that grows one thousand times proportionally with the size of the input, TB has log linear complexity, TC has quadratic complexity and TD has exponential complexity. For n between 0 and 10, the best algorithm is TD because it maintains a slow growth in the number of operations. For n between 10 and almost 100, the best algorithm is TC and for n greater than 100 the best algorithm is TA because it represents the slowest growth rate in the number of operations compared to the growth of the input and the constant 1000 doesn' matters.

# %% [markdown]
# 2. ¿What is the complexity of $O(n!)$
#
# Factorial is the multiplication of all positive integer numbers less than itself, so it grows pretty quickly. The algortihms with this complexity are very slow and could be the worst of the worst-case scenario with the polynomial orders.

# %% [markdown]
# 3. ¿What means $log(log(n))$?
#
# Since $O(\log{n})$ is one of the best complexities, applying the logarithm function twice to the input data will result in fewer operations, having a better complexity and indicating a faster algorithm.

# %% [markdown]
# 4. Rank the following complexities from highest to lowest.
# * $n\log{n}$
# * $2^n$
# * $n!$
# * $n^{2}/2$
# * $n^2 + \log{n}$
# * $n^{2}\log{n}$
# * $n+n^{7}+n^{3}$
# * $\sqrt{n}$
# * $\frac{3}{2}^{n}$
# * $e^{n}$

# %% [markdown]
# From highest to lowest:
#
# * $n+n^{7}+n^{3}$
# * $e^{n}$
# * $n!$
# * $2^n$
# * $n^2 + \log{n}$
# * $n^{2}\log{n}$
# * $n^{2}/2$
# * $\frac{3}{2}^{n}$
# * $n\log{n}$
# * $\sqrt{n}$
